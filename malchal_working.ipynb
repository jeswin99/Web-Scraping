# %% [markdown]
# <a href="https://colab.research.google.com/github/jeswin99/Web-Scraping/blob/main/malchal_working.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Sun Sep 27 19:46:08 2020

@author: jeswin
"""
import re
import ssl
from urllib.request import urlopen as uReq

indices=[]
nameset=[]

for i in range(5):
  my_url = 'https://www.malayalachalachithram.com/movieslist.php?y=2019&p='+str(i+1)
  uClient = uReq(my_url)
  page_html = uClient.read()
  uClient.close()
  indices+=re.findall(r'<dt><a href="movie.php.*?i=(.*?)"',str(page_html))

title={}
release={}
director={}
cast={}

for i in indices:
  my_url='https://www.malayalachalachithram.com/movie.php?i='+i
  uClient = uReq(my_url)
  html = uClient.read()
  uClient.close()
  title[i] = re.findall(r'class="movie" itemprop="name">(.*?)<', str(html))
  release[i] = re.findall(r'itemprop="datePublished">(.*?)<', str(html))
  director[i] = re.findall(r'itemprop="director" itemscope .*?<a itemprop="name".*?>(.*?)<', str(html))
  cast[i] = re.findall(r'itemprop="actor" itemscope .*?<a itemprop="name".*?>(.*?)<', str(html))


print(title)
print(release)
print(director)
print(cast)
# Out:
# {'5261': ['1948 Kaalam Paranjathu (2019)'], '5478': ['Unmaadiyude Maranam (2019)'], '5483': ['Lucifer (2019)'], '5490': ['Moothon (2019)'], '5617': ['Vallikkettu (2019)'], '5631': ['Oru Adaaru Love (2019)'], '5670': ['Old Is Gold (2019)'], '5678': ['Swapnaraajyam (2019)'], '5681': ['Red Signal (2019)'], '5711': ['Sachin (2019)'], '5718': ['Love, Action, Drama (2019)'], '5726': ['Orma (2019)'], '5737': ['Praana (2019)'], '5743': ['Viplavam Jayikkanullathaanu (2019)'], '5754': ['Thenkasikkaattu (2019)'], '5755': ['Ilayaraja (2019)'], '5756': ['Thaakkol (2019)'], '5758': ['The Great Indian Road Movie (2019)'], '5760': ['Nine (2019)'], '5768': ['Nalla Vishesham (2019)'], '5771': ['Kumbalangi Nights (2019)'], '5775': ['Ambili (2019)'], '5778': ['Panthu (2019)'], '5787': ['Oronnonnara Pranayakadha (2019)'], '5789': ['Thankabhasma Kuriyitta Thamburaatti (2019)'], '5797': ['Mere Pyare Deshvaasiyom (2019)'], '5798': ['Vaarthakal Ithuvare (2019)'], '5812': ['Sthree (2019)'], '5818': ['Oru Yama
# ...

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Sun Sep 27 19:46:08 2020

@author: jeswin
"""
import re
import ssl
from urllib.request import urlopen as uReq

indices=[]
nameset=[]

for i in range(5):
  my_url = 'https://www.malayalachalachithram.com/movieslist.php?y=2019&p='+str(i+1)
  uClient = uReq(my_url)
  page_html = uClient.read()
  uClient.close()
  indices+=re.findall(r'<dt><a href="movie.php.*?i=(.*?)"',str(page_html))

title={}
release={}
director={}
cast={}

for i in indices:
  my_url='https://www.malayalachalachithram.com/movie.php?i='+i
  uClient = uReq(my_url)
  html = uClient.read()
  uClient.close()
  dataset[i]["title"] = re.findall(r'class="movie" itemprop="name">(.*?)<', str(html))
  release[i][""] = re.findall(r'itemprop="datePublished">(.*?)<', str(html))
  director[i] = re.findall(r'itemprop="director" itemscope .*?<a itemprop="name".*?>(.*?)<', str(html))
  cast[i] = re.findall(r'itemprop="actor" itemscope .*?<a itemprop="name".*?>(.*?)<', str(html))


print(title)
print(release)
print(director)
print(cast)
# Out:
# {'5261': ['1948 Kaalam Paranjathu (2019)'], '5478': ['Unmaadiyude Maranam (2019)'], '5483': ['Lucifer (2019)'], '5490': ['Moothon (2019)'], '5617': ['Vallikkettu (2019)'], '5631': ['Oru Adaaru Love (2019)'], '5670': ['Old Is Gold (2019)'], '5678': ['Swapnaraajyam (2019)'], '5681': ['Red Signal (2019)'], '5711': ['Sachin (2019)'], '5718': ['Love, Action, Drama (2019)'], '5726': ['Orma (2019)'], '5737': ['Praana (2019)'], '5743': ['Viplavam Jayikkanullathaanu (2019)'], '5754': ['Thenkasikkaattu (2019)'], '5755': ['Ilayaraja (2019)'], '5756': ['Thaakkol (2019)'], '5758': ['The Great Indian Road Movie (2019)'], '5760': ['Nine (2019)'], '5768': ['Nalla Vishesham (2019)'], '5771': ['Kumbalangi Nights (2019)'], '5775': ['Ambili (2019)'], '5778': ['Panthu (2019)'], '5787': ['Oronnonnara Pranayakadha (2019)'], '5789': ['Thankabhasma Kuriyitta Thamburaatti (2019)'], '5797': ['Mere Pyare Deshvaasiyom (2019)'], '5798': ['Vaarthakal Ithuvare (2019)'], '5812': ['Sthree (2019)'], '5818': ['Oru Yama
# ...
